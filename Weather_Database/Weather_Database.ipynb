# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 784

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -139.0333, 'lat': -9.8},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 78.06,
#   'feels_like': 78.91,
#   'temp_min': 78.06,
#   'temp_max': 78.06,
#   'pressure': 1015,
#   'humidity': 71,
#   'sea_level': 1015,
#   'grnd_level': 1007},
#  'visibility': 10000,
#  'wind': {'speed': 21.56, 'deg': 104, 'gust': 21.39},
#  'clouds': {'all': 67},
#  'dt': 1633108611,
#  'sys': {'country': 'PF', 'sunrise': 1633100389, 'sunset': 1633144278},
#  'timezone': -34200,
#  'id': 4020109,
#  'name': 'Atuona',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
        
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | mayumba
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | narsaq
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | namibe
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | half moon bay
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | melilla
# Processing Record 20 of Set 1 | kamenka
# Processing Record 21 of Set 1 | alice springs
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | sal rei
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | ishigaki
# Processing Record 27 of Set 1 | matay
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | lagoa
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | libertador general san martin
# Processing Record 35 of Set 1 | keighley
# Processing Record 36 of Set 1 | fairbanks
# Processing Record 37 of Set 1 | san javier
# Processing Record 38 of Set 1 | uruacu
# Processing Record 39 of Set 1 | sao filipe
# Processing Record 40 of Set 1 | banda aceh
# Processing Record 41 of Set 1 | lorengau
# Processing Record 42 of Set 1 | fortuna
# Processing Record 43 of Set 1 | san ramon
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | deputatskiy
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | wangou
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | sobolevo
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | nome
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | maldonado
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | alofi
# Processing Record 10 of Set 2 | maniitsoq
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | port lincoln
# Processing Record 13 of Set 2 | arak
# Processing Record 14 of Set 2 | farah
# Processing Record 15 of Set 2 | hailar
# Processing Record 16 of Set 2 | quatre cocos
# Processing Record 17 of Set 2 | vanimo
# Processing Record 18 of Set 2 | vardo
# Processing Record 19 of Set 2 | shitanjing
# Processing Record 20 of Set 2 | bilibino
# Processing Record 21 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 2 | nola
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | madras
# Processing Record 26 of Set 2 | yulara
# Processing Record 27 of Set 2 | najran
# Processing Record 28 of Set 2 | kampong cham
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | makubetsu
# Processing Record 31 of Set 2 | hualmay
# Processing Record 32 of Set 2 | changli
# Processing Record 33 of Set 2 | dingle
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | darnah
# Processing Record 36 of Set 2 | finnsnes
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | port said
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | jinotega
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | bilma
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | amahai
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | aykhal
# Processing Record 1 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 3 | saint-pierre
# Processing Record 3 of Set 3 | puerto leguizamo
# Processing Record 4 of Set 3 | barra patuca
# Processing Record 5 of Set 3 | sawtell
# Processing Record 6 of Set 3 | laguna
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | gari
# Processing Record 9 of Set 3 | nouakchott
# Processing Record 10 of Set 3 | ust-tsilma
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | conceicao do araguaia
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | rovenki
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | aswan
# Processing Record 18 of Set 3 | susanville
# Processing Record 19 of Set 3 | tangancicuaro
# City not found. Skipping...
# Processing Record 20 of Set 3 | naze
# Processing Record 21 of Set 3 | sefophe
# Processing Record 22 of Set 3 | abbeville
# Processing Record 23 of Set 3 | mahebourg
# Processing Record 24 of Set 3 | leningradskiy
# Processing Record 25 of Set 3 | san cristobal
# Processing Record 26 of Set 3 | banjar
# Processing Record 27 of Set 3 | morgan city
# Processing Record 28 of Set 3 | sussex
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | havre
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | muncar
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | xining
# Processing Record 36 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 3 | christchurch
# Processing Record 38 of Set 3 | kelo
# Processing Record 39 of Set 3 | barrow
# Processing Record 40 of Set 3 | shimoda
# Processing Record 41 of Set 3 | saint-philippe
# Processing Record 42 of Set 3 | bonavista
# Processing Record 43 of Set 3 | cape town
# Processing Record 44 of Set 3 | camacha
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | abtenau
# Processing Record 47 of Set 3 | tautira
# Processing Record 48 of Set 3 | sitka
# Processing Record 49 of Set 3 | tasiilaq
# Processing Record 50 of Set 3 | oktyabrskoye
# Processing Record 1 of Set 4 | wahiawa
# Processing Record 2 of Set 4 | kanchanaburi
# Processing Record 3 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 5 of Set 4 | bantva
# Processing Record 6 of Set 4 | taoudenni
# Processing Record 7 of Set 4 | winton
# Processing Record 8 of Set 4 | linxia
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | aksarka
# Processing Record 11 of Set 4 | te anau
# Processing Record 12 of Set 4 | paita
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | tamandare
# Processing Record 15 of Set 4 | mitu
# Processing Record 16 of Set 4 | safranbolu
# Processing Record 17 of Set 4 | eyl
# Processing Record 18 of Set 4 | fuglebjerg
# Processing Record 19 of Set 4 | vestmannaeyjar
# Processing Record 20 of Set 4 | sayyan
# Processing Record 21 of Set 4 | rio negrinho
# Processing Record 22 of Set 4 | tefe
# Processing Record 23 of Set 4 | port macquarie
# Processing Record 24 of Set 4 | wilmington
# Processing Record 25 of Set 4 | saldanha
# Processing Record 26 of Set 4 | arraial do cabo
# Processing Record 27 of Set 4 | airai
# Processing Record 28 of Set 4 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | flin flon
# Processing Record 31 of Set 4 | lakhimpur
# Processing Record 32 of Set 4 | asau
# Processing Record 33 of Set 4 | hameenlinna
# Processing Record 34 of Set 4 | noumea
# Processing Record 35 of Set 4 | broome
# Processing Record 36 of Set 4 | havelock
# Processing Record 37 of Set 4 | gizo
# Processing Record 38 of Set 4 | nanortalik
# Processing Record 39 of Set 4 | itarema
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | ust-maya
# Processing Record 43 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 44 of Set 4 | manggar
# Processing Record 45 of Set 4 | pangoa
# Processing Record 46 of Set 4 | wagar
# Processing Record 47 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 4 | viedma
# Processing Record 49 of Set 4 | sembakung
# Processing Record 50 of Set 4 | cam pha
# City not found. Skipping...
# Processing Record 1 of Set 5 | iqaluit
# Processing Record 2 of Set 5 | jamestown
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | baruun-urt
# Processing Record 5 of Set 5 | ilulissat
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | bubaque
# Processing Record 8 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 9 of Set 5 | gamba
# Processing Record 10 of Set 5 | chingirlau
# Processing Record 11 of Set 5 | trollhattan
# Processing Record 12 of Set 5 | palu
# Processing Record 13 of Set 5 | atar
# Processing Record 14 of Set 5 | aklavik
# Processing Record 15 of Set 5 | mayo
# Processing Record 16 of Set 5 | melchor de mencos
# Processing Record 17 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 18 of Set 5 | sipe sipe
# Processing Record 19 of Set 5 | solnechnyy
# Processing Record 20 of Set 5 | izhma
# Processing Record 21 of Set 5 | shache
# Processing Record 22 of Set 5 | waipawa
# Processing Record 23 of Set 5 | port keats
# Processing Record 24 of Set 5 | makakilo city
# Processing Record 25 of Set 5 | puerto baquerizo moreno
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | natal
# Processing Record 28 of Set 5 | adrar
# Processing Record 29 of Set 5 | vagur
# Processing Record 30 of Set 5 | mountain home
# Processing Record 31 of Set 5 | sorland
# Processing Record 32 of Set 5 | douentza
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | klaksvik
# Processing Record 35 of Set 5 | faya
# Processing Record 36 of Set 5 | omboue
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | eureka
# Processing Record 39 of Set 5 | prieska
# Processing Record 40 of Set 5 | korla
# Processing Record 41 of Set 5 | helsinki
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | kramat
# Processing Record 44 of Set 5 | lokosovo
# Processing Record 45 of Set 5 | nunchia
# Processing Record 46 of Set 5 | dahra
# Processing Record 47 of Set 5 | huarmey
# Processing Record 48 of Set 5 | seymchan
# Processing Record 49 of Set 5 | sharya
# Processing Record 50 of Set 5 | kiama
# Processing Record 1 of Set 6 | buon me thuot
# City not found. Skipping...
# Processing Record 2 of Set 6 | beringovskiy
# Processing Record 3 of Set 6 | shirokiy
# Processing Record 4 of Set 6 | westport
# Processing Record 5 of Set 6 | santa rosalia
# Processing Record 6 of Set 6 | batagay-alyta
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | lebu
# Processing Record 9 of Set 6 | coari
# Processing Record 10 of Set 6 | nishihara
# Processing Record 11 of Set 6 | hami
# Processing Record 12 of Set 6 | tauranga
# Processing Record 13 of Set 6 | zhigalovo
# Processing Record 14 of Set 6 | benito juarez
# Processing Record 15 of Set 6 | kalmunai
# Processing Record 16 of Set 6 | shelburne
# Processing Record 17 of Set 6 | ampanihy
# Processing Record 18 of Set 6 | qarqin
# Processing Record 19 of Set 6 | taveta
# Processing Record 20 of Set 6 | lobez
# Processing Record 21 of Set 6 | ossora
# Processing Record 22 of Set 6 | farim
# Processing Record 23 of Set 6 | pathein
# Processing Record 24 of Set 6 | teixoso
# Processing Record 25 of Set 6 | sabha
# Processing Record 26 of Set 6 | anadyr
# Processing Record 27 of Set 6 | winnemucca
# Processing Record 28 of Set 6 | lemesos
# City not found. Skipping...
# Processing Record 29 of Set 6 | flinders
# Processing Record 30 of Set 6 | geraldton
# Processing Record 31 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 6 | kuanhsi
# City not found. Skipping...
# Processing Record 33 of Set 6 | yaring
# Processing Record 34 of Set 6 | havoysund
# Processing Record 35 of Set 6 | college
# Processing Record 36 of Set 6 | baykit
# Processing Record 37 of Set 6 | iberia
# Processing Record 38 of Set 6 | chapais
# Processing Record 39 of Set 6 | mudyuga
# City not found. Skipping...
# Processing Record 40 of Set 6 | alihe
# Processing Record 41 of Set 6 | kavieng
# Processing Record 42 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 6 | muzquiz
# City not found. Skipping...
# Processing Record 44 of Set 6 | tungor
# Processing Record 45 of Set 6 | vaxjo
# Processing Record 46 of Set 6 | sembe
# Processing Record 47 of Set 6 | merauke
# Processing Record 48 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 6 | manadhoo
# Processing Record 50 of Set 6 | coquimbo
# Processing Record 1 of Set 7 | ukiah
# Processing Record 2 of Set 7 | abong mbang
# Processing Record 3 of Set 7 | liverpool
# Processing Record 4 of Set 7 | margate
# Processing Record 5 of Set 7 | kibala
# Processing Record 6 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 7 | lima
# Processing Record 8 of Set 7 | husavik
# Processing Record 9 of Set 7 | palimbang
# Processing Record 10 of Set 7 | hovd
# Processing Record 11 of Set 7 | tateyama
# Processing Record 12 of Set 7 | aparecida do taboado
# Processing Record 13 of Set 7 | aseri
# Processing Record 14 of Set 7 | kotelnikovo
# Processing Record 15 of Set 7 | ust-kut
# Processing Record 16 of Set 7 | port hedland
# Processing Record 17 of Set 7 | port hardy
# Processing Record 18 of Set 7 | galyugayevskaya
# Processing Record 19 of Set 7 | shieli
# Processing Record 20 of Set 7 | esperance
# Processing Record 21 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 7 | naruja
# Processing Record 23 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 7 | uyuni
# Processing Record 25 of Set 7 | gisborne
# Processing Record 26 of Set 7 | guerrero negro
# Processing Record 27 of Set 7 | maraba
# Processing Record 28 of Set 7 | erdenet
# Processing Record 29 of Set 7 | savalou
# Processing Record 30 of Set 7 | mocuba
# Processing Record 31 of Set 7 | tomatlan
# Processing Record 32 of Set 7 | sur
# Processing Record 33 of Set 7 | sibolga
# Processing Record 34 of Set 7 | severnyy
# Processing Record 35 of Set 7 | manta
# Processing Record 36 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 7 | adolfo lopez mateos
# Processing Record 38 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 7 | lunino
# Processing Record 40 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 41 of Set 7 | kelc
# Processing Record 42 of Set 7 | borger
# Processing Record 43 of Set 7 | pacific grove
# Processing Record 44 of Set 7 | upata
# Processing Record 45 of Set 7 | stepnogorsk
# Processing Record 46 of Set 7 | dhadar
# Processing Record 47 of Set 7 | norman wells
# Processing Record 48 of Set 7 | manavgat
# Processing Record 49 of Set 7 | estelle
# Processing Record 50 of Set 7 | zheshart
# Processing Record 1 of Set 8 | redcliffe
# Processing Record 2 of Set 8 | east massapequa
# Processing Record 3 of Set 8 | sao felix do xingu
# Processing Record 4 of Set 8 | hofn
# Processing Record 5 of Set 8 | tual
# Processing Record 6 of Set 8 | yuli
# Processing Record 7 of Set 8 | tura
# Processing Record 8 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 8 | wewak
# Processing Record 10 of Set 8 | vanavara
# Processing Record 11 of Set 8 | los andes
# Processing Record 12 of Set 8 | beroroha
# Processing Record 13 of Set 8 | araouane
# Processing Record 14 of Set 8 | lulea
# Processing Record 15 of Set 8 | coruripe
# Processing Record 16 of Set 8 | mount gambier
# Processing Record 17 of Set 8 | bara
# Processing Record 18 of Set 8 | rawlins
# Processing Record 19 of Set 8 | meulaboh
# Processing Record 20 of Set 8 | buraydah
# Processing Record 21 of Set 8 | lata
# Processing Record 22 of Set 8 | along
# Processing Record 23 of Set 8 | marsa matruh
# Processing Record 24 of Set 8 | talnakh
# Processing Record 25 of Set 8 | nelson bay
# Processing Record 26 of Set 8 | rovnoye
# Processing Record 27 of Set 8 | labuhan
# Processing Record 28 of Set 8 | kuusamo
# Processing Record 29 of Set 8 | cabo san lucas
# Processing Record 30 of Set 8 | nogliki
# Processing Record 31 of Set 8 | rurrenabaque
# Processing Record 32 of Set 8 | kawalu
# Processing Record 33 of Set 8 | toyooka
# Processing Record 34 of Set 8 | la tuque
# Processing Record 35 of Set 8 | sisimiut
# Processing Record 36 of Set 8 | itupiranga
# Processing Record 37 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 8 | lastoursville
# Processing Record 39 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 8 | komsomolskiy
# Processing Record 41 of Set 8 | la ronge
# Processing Record 42 of Set 8 | robertsport
# Processing Record 43 of Set 8 | sao joao da barra
# Processing Record 44 of Set 8 | kutum
# Processing Record 45 of Set 8 | soe
# Processing Record 46 of Set 8 | teknaf
# Processing Record 47 of Set 8 | tocopilla
# Processing Record 48 of Set 8 | kargasok
# Processing Record 49 of Set 8 | tarko-sale
# Processing Record 50 of Set 8 | yerbogachen
# Processing Record 1 of Set 9 | pirenopolis
# Processing Record 2 of Set 9 | stornoway
# Processing Record 3 of Set 9 | angoche
# Processing Record 4 of Set 9 | yabassi
# Processing Record 5 of Set 9 | north platte
# Processing Record 6 of Set 9 | coro
# Processing Record 7 of Set 9 | changji
# Processing Record 8 of Set 9 | stabat
# Processing Record 9 of Set 9 | conceicao da barra
# Processing Record 10 of Set 9 | punta alta
# Processing Record 11 of Set 9 | gushikawa
# Processing Record 12 of Set 9 | mukerian
# Processing Record 13 of Set 9 | niltepec
# Processing Record 14 of Set 9 | kununurra
# Processing Record 15 of Set 9 | muli
# Processing Record 16 of Set 9 | erattupetta
# Processing Record 17 of Set 9 | soria
# Processing Record 18 of Set 9 | boone
# Processing Record 19 of Set 9 | ust-omchug
# Processing Record 20 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 9 | saint-michel-des-saints
# Processing Record 22 of Set 9 | san vicente
# Processing Record 23 of Set 9 | boa vista
# Processing Record 24 of Set 9 | hamilton
# Processing Record 25 of Set 9 | neyyattinkara
# Processing Record 26 of Set 9 | houma
# Processing Record 27 of Set 9 | tiksi
# Processing Record 28 of Set 9 | tessalit
# Processing Record 29 of Set 9 | manitouwadge
# Processing Record 30 of Set 9 | olafsvik
# Processing Record 31 of Set 9 | sakakah
# Processing Record 32 of Set 9 | iskateley
# Processing Record 33 of Set 9 | cap malheureux
# Processing Record 34 of Set 9 | ruteng
# Processing Record 35 of Set 9 | kosjeric
# Processing Record 36 of Set 9 | pijijiapan
# Processing Record 37 of Set 9 | manono
# Processing Record 38 of Set 9 | candolim
# Processing Record 39 of Set 9 | erzin
# Processing Record 40 of Set 9 | antsohihy
# Processing Record 41 of Set 9 | hambantota
# Processing Record 42 of Set 9 | sarh
# Processing Record 43 of Set 9 | lagos
# Processing Record 44 of Set 9 | namatanai
# Processing Record 45 of Set 9 | mayskiy
# Processing Record 46 of Set 9 | nikolskoye
# Processing Record 47 of Set 9 | pedasi
# Processing Record 48 of Set 9 | urumqi
# Processing Record 49 of Set 9 | lensk
# Processing Record 50 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 10 | bandar penggaram
# City not found. Skipping...
# Processing Record 2 of Set 10 | kaeo
# Processing Record 3 of Set 10 | khandyga
# Processing Record 4 of Set 10 | buta
# Processing Record 5 of Set 10 | madimba
# Processing Record 6 of Set 10 | seoul
# Processing Record 7 of Set 10 | kwale
# Processing Record 8 of Set 10 | tangwani
# Processing Record 9 of Set 10 | el carmen
# Processing Record 10 of Set 10 | leshukonskoye
# Processing Record 11 of Set 10 | lompoc
# Processing Record 12 of Set 10 | kathu
# Processing Record 13 of Set 10 | muzambinho
# Processing Record 14 of Set 10 | okhotsk
# Processing Record 15 of Set 10 | arkhara
# Processing Record 16 of Set 10 | bereda
# Processing Record 17 of Set 10 | mlonggo
# Processing Record 18 of Set 10 | avera
# Processing Record 19 of Set 10 | alegrete
# Processing Record 20 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 10 | jinchang
# Processing Record 22 of Set 10 | lasa
# Processing Record 23 of Set 10 | miri
# Processing Record 24 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 10 | cubuk
# Processing Record 26 of Set 10 | bandarbeyla
# Processing Record 27 of Set 10 | casablanca
# Processing Record 28 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 10 | liaocheng
# Processing Record 30 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 10 | terney
# Processing Record 32 of Set 10 | oriximina
# Processing Record 33 of Set 10 | acajutla
# Processing Record 34 of Set 10 | juneau
# Processing Record 35 of Set 10 | kumluca
# Processing Record 36 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 10 | mehamn
# Processing Record 38 of Set 10 | chachapoyas
# Processing Record 39 of Set 10 | raudeberg
# Processing Record 40 of Set 10 | samarai
# Processing Record 41 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 10 | enshi
# Processing Record 43 of Set 10 | visnes
# Processing Record 44 of Set 10 | orumiyeh
# Processing Record 45 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 10 | bonthe
# Processing Record 47 of Set 10 | mbekenyera
# Processing Record 48 of Set 10 | pangnirtung
# Processing Record 49 of Set 10 | hasaki
# Processing Record 50 of Set 10 | kyren
# Processing Record 1 of Set 11 | pisco
# Processing Record 2 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 11 | am timan
# Processing Record 4 of Set 11 | perth
# Processing Record 5 of Set 11 | maunabo
# Processing Record 6 of Set 11 | muros
# Processing Record 7 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 11 | muravlenko
# Processing Record 9 of Set 11 | zhigansk
# Processing Record 10 of Set 11 | port lavaca
# Processing Record 11 of Set 11 | coihaique
# Processing Record 12 of Set 11 | katangli
# Processing Record 13 of Set 11 | vaike-maarja
# Processing Record 14 of Set 11 | mandeville
# Processing Record 15 of Set 11 | namtsy
# Processing Record 16 of Set 11 | mora
# Processing Record 17 of Set 11 | weatherford
# Processing Record 18 of Set 11 | emerald
# Processing Record 19 of Set 11 | cayenne
# Processing Record 20 of Set 11 | alakurtti
# Processing Record 21 of Set 11 | chicama
# Processing Record 22 of Set 11 | tabuk
# Processing Record 23 of Set 11 | san joaquin
# Processing Record 24 of Set 11 | general pico
# Processing Record 25 of Set 11 | udachnyy
# Processing Record 26 of Set 11 | dupnica
# City not found. Skipping...
# Processing Record 27 of Set 11 | canico
# Processing Record 28 of Set 11 | chifeng
# Processing Record 29 of Set 11 | dalbandin
# Processing Record 30 of Set 11 | calama
# Processing Record 31 of Set 11 | nyuzen
# Processing Record 32 of Set 11 | nago
# Processing Record 33 of Set 11 | pemba
# Processing Record 34 of Set 11 | poum
# Processing Record 35 of Set 11 | ostrovnoy
# Processing Record 36 of Set 11 | belyy yar
# Processing Record 37 of Set 11 | svirsk
# Processing Record 38 of Set 11 | strelka
# Processing Record 39 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 11 | henties bay
# Processing Record 41 of Set 11 | tahta
# Processing Record 42 of Set 11 | cascais
# Processing Record 43 of Set 11 | chongwe
# Processing Record 44 of Set 11 | port-gentil
# Processing Record 45 of Set 11 | longfeng
# Processing Record 46 of Set 11 | voineasa
# Processing Record 47 of Set 11 | los llanos de aridane
# Processing Record 48 of Set 11 | chiredzi
# Processing Record 49 of Set 11 | tashtagol
# Processing Record 50 of Set 11 | vostok
# Processing Record 1 of Set 12 | coahuayana
# Processing Record 2 of Set 12 | methven
# Processing Record 3 of Set 12 | anloga
# Processing Record 4 of Set 12 | richards bay
# Processing Record 5 of Set 12 | alappuzha
# Processing Record 6 of Set 12 | torbay
# Processing Record 7 of Set 12 | krasnogorskiy
# Processing Record 8 of Set 12 | vysha
# Processing Record 9 of Set 12 | coaticook
# Processing Record 10 of Set 12 | zhezkazgan
# Processing Record 11 of Set 12 | inhambane
# Processing Record 12 of Set 12 | amga
# Processing Record 13 of Set 12 | chalchihuites
# Processing Record 14 of Set 12 | praia da vitoria
# Processing Record 15 of Set 12 | luderitz
# Processing Record 16 of Set 12 | yuncheng
# Processing Record 17 of Set 12 | goiatuba
# Processing Record 18 of Set 12 | buala
# Processing Record 19 of Set 12 | fort nelson
# Processing Record 20 of Set 12 | niny
# Processing Record 21 of Set 12 | sao gabriel da cachoeira
# Processing Record 22 of Set 12 | guinticgan
# Processing Record 23 of Set 12 | suba
# Processing Record 24 of Set 12 | grootfontein
# Processing Record 25 of Set 12 | shushenskoye
# Processing Record 26 of Set 12 | hienghene
# Processing Record 27 of Set 12 | batemans bay
# Processing Record 28 of Set 12 | cherskiy
# Processing Record 29 of Set 12 | dhidhdhoo
# Processing Record 30 of Set 12 | chipata
# Processing Record 31 of Set 12 | corning
# Processing Record 32 of Set 12 | crotone
# Processing Record 33 of Set 12 | maragogi
# Processing Record 34 of Set 12 | grand gaube
# Processing Record 35 of Set 12 | jishou
# Processing Record 36 of Set 12 | aliwal north
# Processing Record 37 of Set 12 | alto araguaia
# Processing Record 38 of Set 12 | novaya bryan
# Processing Record 39 of Set 12 | alexandria
# Processing Record 40 of Set 12 | tchollire
# Processing Record 41 of Set 12 | tame
# Processing Record 42 of Set 12 | abeche
# Processing Record 43 of Set 12 | darab
# Processing Record 44 of Set 12 | ibotirama
# Processing Record 45 of Set 12 | ayan
# Processing Record 46 of Set 12 | oum hadjer
# Processing Record 47 of Set 12 | srandakan
# Processing Record 48 of Set 12 | kirakira
# Processing Record 49 of Set 12 | senneterre
# Processing Record 50 of Set 12 | bowen
# Processing Record 1 of Set 13 | penzance
# Processing Record 2 of Set 13 | takoradi
# Processing Record 3 of Set 13 | tuatapere
# Processing Record 4 of Set 13 | birjand
# Processing Record 5 of Set 13 | mackay
# Processing Record 6 of Set 13 | san quintin
# Processing Record 7 of Set 13 | touros
# Processing Record 8 of Set 13 | palora
# Processing Record 9 of Set 13 | la massana
# Processing Record 10 of Set 13 | leczna
# Processing Record 11 of Set 13 | aktash
# Processing Record 12 of Set 13 | kanelovskaya
# Processing Record 13 of Set 13 | chimore
# Processing Record 14 of Set 13 | kholmogory
# Processing Record 15 of Set 13 | victor harbor
# Processing Record 16 of Set 13 | beloha
# Processing Record 17 of Set 13 | galveston
# Processing Record 18 of Set 13 | kotlas
# Processing Record 19 of Set 13 | sovetskiy
# Processing Record 20 of Set 13 | tucuma
# Processing Record 21 of Set 13 | hukuntsi
# Processing Record 22 of Set 13 | tra vinh
# Processing Record 23 of Set 13 | marawi
# Processing Record 24 of Set 13 | goderich
# Processing Record 25 of Set 13 | ziro
# Processing Record 26 of Set 13 | ust-karsk
# Processing Record 27 of Set 13 | west fargo
# Processing Record 28 of Set 13 | luangwa
# Processing Record 29 of Set 13 | rock sound
# Processing Record 30 of Set 13 | cockburn town
# Processing Record 31 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 13 | senno
# Processing Record 33 of Set 13 | kachug
# Processing Record 34 of Set 13 | marsabit
# Processing Record 35 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 13 | pevek
# Processing Record 37 of Set 13 | bobrovka
# Processing Record 38 of Set 13 | siuna
# Processing Record 39 of Set 13 | piacabucu
# Processing Record 40 of Set 13 | gat
# Processing Record 41 of Set 13 | porto novo
# Processing Record 42 of Set 13 | bonito
# Processing Record 43 of Set 13 | jalu
# Processing Record 44 of Set 13 | khani
# Processing Record 45 of Set 13 | vucje
# Processing Record 46 of Set 13 | riyadh
# Processing Record 47 of Set 13 | sungaipenuh
# Processing Record 48 of Set 13 | san andres
# Processing Record 49 of Set 13 | fort smith
# Processing Record 50 of Set 13 | grenada
# Processing Record 1 of Set 14 | yinchuan
# Processing Record 2 of Set 14 | acapulco
# Processing Record 3 of Set 14 | urucara
# Processing Record 4 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 14 | jinxiang
# Processing Record 6 of Set 14 | murindo
# Processing Record 7 of Set 14 | boddam
# Processing Record 8 of Set 14 | grindavik
# Processing Record 9 of Set 14 | bergen
# Processing Record 10 of Set 14 | filadelfia
# Processing Record 11 of Set 14 | muisne
# Processing Record 12 of Set 14 | cornelio procopio
# Processing Record 13 of Set 14 | novoleushkovskaya
# Processing Record 14 of Set 14 | babu
# Processing Record 15 of Set 14 | joigny
# Processing Record 16 of Set 14 | figeac
# Processing Record 17 of Set 14 | brigantine
# Processing Record 18 of Set 14 | pokhara
# Processing Record 19 of Set 14 | boali
# Processing Record 20 of Set 14 | knysna
# Processing Record 21 of Set 14 | high level
# Processing Record 22 of Set 14 | burnie
# Processing Record 23 of Set 14 | guanica
# Processing Record 24 of Set 14 | zemio
# Processing Record 25 of Set 14 | ledyard
# Processing Record 26 of Set 14 | acarau
# Processing Record 27 of Set 14 | tanshui
# City not found. Skipping...
# Processing Record 28 of Set 14 | mount darwin
# Processing Record 29 of Set 14 | segezha
# Processing Record 30 of Set 14 | nacozari
# Processing Record 31 of Set 14 | seoni
# Processing Record 32 of Set 14 | nicoya
# Processing Record 33 of Set 14 | arona
# Processing Record 34 of Set 14 | vila velha
# Processing Record 35 of Set 14 | sola
# Processing Record 36 of Set 14 | pitimbu
# Processing Record 37 of Set 14 | port augusta
# Processing Record 38 of Set 14 | bikaner
# Processing Record 39 of Set 14 | melfort
# Processing Record 40 of Set 14 | rio gallegos
# Processing Record 41 of Set 14 | neyshabur
# Processing Record 42 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 43 of Set 14 | nkayi
# Processing Record 44 of Set 14 | mackenzie
# Processing Record 45 of Set 14 | ucluelet
# Processing Record 46 of Set 14 | aripuana
# Processing Record 47 of Set 14 | sungairaya
# Processing Record 48 of Set 14 | lashio
# Processing Record 49 of Set 14 | roald
# Processing Record 50 of Set 14 | matagami
# Processing Record 1 of Set 15 | nacogdoches
# Processing Record 2 of Set 15 | sekoma
# Processing Record 3 of Set 15 | mangrol
# Processing Record 4 of Set 15 | waingapu
# Processing Record 5 of Set 15 | mombetsu
# Processing Record 6 of Set 15 | mattru
# Processing Record 7 of Set 15 | ogdensburg
# Processing Record 8 of Set 15 | bayir
# Processing Record 9 of Set 15 | makaryev
# Processing Record 10 of Set 15 | tottori
# Processing Record 11 of Set 15 | portland
# Processing Record 12 of Set 15 | brae
# Processing Record 13 of Set 15 | statesboro
# Processing Record 14 of Set 15 | ugoofaaru
# Processing Record 15 of Set 15 | teahupoo
# Processing Record 16 of Set 15 | codrington
# Processing Record 17 of Set 15 | yar-sale
# Processing Record 18 of Set 15 | vikhorevka
# Processing Record 19 of Set 15 | taltal
# Processing Record 20 of Set 15 | san jeronimo
# Processing Record 21 of Set 15 | guaranda
# Processing Record 22 of Set 15 | coolum beach
# Processing Record 23 of Set 15 | ouahigouya
# Processing Record 24 of Set 15 | camana
# Processing Record 25 of Set 15 | padang
# Processing Record 26 of Set 15 | guia de isora
# Processing Record 27 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 15 | winona
# Processing Record 29 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 30 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 15 | kayerkan
# Processing Record 32 of Set 15 | vitimskiy
# City not found. Skipping...
# Processing Record 33 of Set 15 | ihosy
# Processing Record 34 of Set 15 | jumla
# Processing Record 35 of Set 15 | powell river
# Processing Record 36 of Set 15 | morrinhos
# Processing Record 37 of Set 15 | nosy varika
# Processing Record 38 of Set 15 | isangel
# Processing Record 39 of Set 15 | kudahuvadhoo
# Processing Record 40 of Set 15 | goure
# Processing Record 41 of Set 15 | puerto escondido
# Processing Record 42 of Set 15 | dzhebariki-khaya
# Processing Record 43 of Set 15 | creel
# Processing Record 44 of Set 15 | jackson
# Processing Record 45 of Set 15 | antofagasta
# Processing Record 46 of Set 15 | carutapera
# Processing Record 47 of Set 15 | san policarpo
# Processing Record 48 of Set 15 | burns lake
# Processing Record 49 of Set 15 | staryy nadym
# Processing Record 50 of Set 15 | maromitsa
# Processing Record 1 of Set 16 | odweyne
# Processing Record 2 of Set 16 | svetlyy
# Processing Record 3 of Set 16 | kijang
# Processing Record 4 of Set 16 | champasak
# Processing Record 5 of Set 16 | astoria
# Processing Record 6 of Set 16 | salinopolis
# Processing Record 7 of Set 16 | maraa
# Processing Record 8 of Set 16 | garden city
# Processing Record 9 of Set 16 | wajid
# Processing Record 10 of Set 16 | la sarre
# Processing Record 11 of Set 16 | banmo
# City not found. Skipping...
# Processing Record 12 of Set 16 | heishan
# Processing Record 13 of Set 16 | tetouan
# Processing Record 14 of Set 16 | egvekinot
# Processing Record 15 of Set 16 | ikot ekpene
# Processing Record 16 of Set 16 | beihai
# Processing Record 17 of Set 16 | safford
# Processing Record 18 of Set 16 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 16 | zambrow
# Processing Record 20 of Set 16 | ozorkow
# Processing Record 21 of Set 16 | cozumel
# Processing Record 22 of Set 16 | paro
# Processing Record 23 of Set 16 | ketchikan
# Processing Record 24 of Set 16 | broken hill
# Processing Record 25 of Set 16 | lahan
# Processing Record 26 of Set 16 | abha
# Processing Record 27 of Set 16 | ewo
# Processing Record 28 of Set 16 | sao francisco
# Processing Record 29 of Set 16 | redmond
# Processing Record 30 of Set 16 | turinsk
# Processing Record 31 of Set 16 | weston
# Processing Record 32 of Set 16 | bend
# Processing Record 33 of Set 16 | alyangula
# Processing Record 34 of Set 16 | vila franca do campo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus -34.4187   19.2345     59.90        79          98
# 1       Rikitea -23.1203 -134.9692     73.09        73           6
# 2  Punta Arenas -53.1500  -70.9167     44.71        53          75
# 3   New Norfolk -42.7826  147.0587     55.76        81         100
# 4       Mayumba  -3.4320   10.6554     76.46        84          98
# 5  San Patricio  28.0170  -97.5169     78.89        79         100
# 6       Mataura -46.1927  168.8643     46.47        98         100
# 7        Narsaq  60.9167  -46.0500     44.82        34           2
# 8       Ushuaia -54.8000  -68.3000     37.06        87          75
# 9  Puerto Ayora  -0.7393  -90.3518     78.76        82          88
#
#    Wind Speed Country Current Description
# 0        4.92      ZA     overcast clouds
# 1       19.01      PF           clear sky
# 2       24.16      CL          light rain
# 3        1.92      AU          light rain
# 4        7.78      GA     overcast clouds
# 5        9.08      US       moderate rain
# 6        2.15      NZ     overcast clouds
# 7        1.54      GL           clear sky
# 8        8.05      AR          light rain
# 9       10.40      EC     overcast clouds

# %%
reorder_city_data = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[reorder_city_data]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.4187   19.2345     59.90        79          98
# 1       Rikitea      PF -23.1203 -134.9692     73.09        73           6
# 2  Punta Arenas      CL -53.1500  -70.9167     44.71        53          75
# 3   New Norfolk      AU -42.7826  147.0587     55.76        81         100
# 4       Mayumba      GA  -3.4320   10.6554     76.46        84          98
# 5  San Patricio      US  28.0170  -97.5169     78.89        79         100
# 6       Mataura      NZ -46.1927  168.8643     46.47        98         100
# 7        Narsaq      GL  60.9167  -46.0500     44.82        34           2
# 8       Ushuaia      AR -54.8000  -68.3000     37.06        87          75
# 9  Puerto Ayora      EC  -0.7393  -90.3518     78.76        82          88
#
#    Wind Speed Current Description
# 0        4.92     overcast clouds
# 1       19.01           clear sky
# 2       24.16          light rain
# 3        1.92          light rain
# 4        7.78     overcast clouds
# 5        9.08       moderate rain
# 6        2.15     overcast clouds
# 7        1.54           clear sky
# 8        8.05          light rain
# 9       10.40     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
